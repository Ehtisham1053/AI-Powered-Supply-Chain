# %%
try:
  import pandas as pd
  import numpy as np
  import os
  import joblib
  import lightgbm as lgb
  import matplotlib.pyplot as plt
  import seaborn as sns
  from lightgbm import early_stopping
  from sklearn.ensemble import RandomForestRegressor
  from sklearn.model_selection import train_test_split
  from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
  from tqdm import tqdm
except Exception as e:
  print(e)
# Out:
# No module named 'matplotlib'

# %%
df = pd.read_csv("train (1).csv")

# %%
df.head(1)
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13

# %%
# Pre-processing
def load_and_preprocess(df):

    df['date'] = pd.to_datetime(df['date'])
    df['sales'] = df['sales'].fillna(0)
    df = df.sort_values(by=['store', 'item', 'date']).reset_index(drop=True)
    return df

# %%
def add_date_features(df):
    # 🔍 Ensure 'date' column is in datetime format (in-place and safe)
    if not pd.api.types.is_datetime64_any_dtype(df['date']):
        df['date'] = pd.to_datetime(df['date'], errors='coerce')  # invalid parsing becomes NaT
    
    # ✅ Drop rows where date conversion failed
    df = df.dropna(subset=['date'])

    # Now safely extract features
    df['day'] = df['date'].dt.day
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['day_of_week'] = df['date'].dt.dayofweek
    df['weekend'] = df['day_of_week'].isin([5, 6]).astype(int)
    df['quarter'] = df['date'].dt.quarter

    return df

# %%
# Feature Engineering
def add_sales_timeseries_metrics(df):
    df['sales_1_day_ago'] = df.groupby(['store', 'item'])['sales'].shift(1)
    df['sales_7_days_ago'] = df.groupby(['store', 'item'])['sales'].shift(7)
    df['rolling_14_day_sales'] = df.groupby(['store', 'item'])['sales'].rolling(window=14, min_periods=1).sum().reset_index(drop=True)
    df['rolling_28_day_sales'] = df.groupby(['store', 'item'])['sales'].rolling(window=28, min_periods=1).sum().reset_index(drop=True)
    df['mean_sales'] = df.groupby(['store', 'item'])['sales'].expanding().mean().reset_index(drop=True)
    return df

# %%
# Target variables
def create_targets(df):
    df['target_7_day_sales'] = df.groupby(['store', 'item'])['sales'].shift(-1).rolling(window=7, min_periods=1).sum().reset_index(drop=True)
    df['target_30_day_sales'] = df.groupby(['store', 'item'])['sales'].shift(-1).rolling(window=30, min_periods=1).sum().reset_index(drop=True)
    return df

# %%
def train_and_save_models_from_df(df, model_dir='models_30', target_col='target_30_day_sales'):
    os.makedirs(model_dir, exist_ok=True)

    # Add features
    df = add_sales_timeseries_metrics(df)
    df = add_date_features(df)
    df = create_targets(df)

    features = [
        'sales_1_day_ago', 'sales_7_days_ago', 'rolling_14_day_sales',
        'rolling_28_day_sales', 'mean_sales', 'day', 'month', 'year',
        'day_of_week', 'weekend', 'quarter'
    ]

    grouped = df.groupby(['store', 'item'])

    for (store, item), group in grouped:
        group = group.dropna(subset=features + [target_col])
        if group.shape[0] < 30:
            print(f"Skipping Store {store}, Item {item} — not enough data")
            continue

        X = group[features]
        y = group[target_col]

        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X, y)

        model_path = os.path.join(model_dir, f"{store}_{item}_{target_col}.pkl")
        joblib.dump(model, model_path)
        print(f"✅ Model saved: {model_path}")

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_and_save_models_from_df(df)
# Out:
# ✅ Model saved: models_30\1_1_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_2_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_3_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_4_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_5_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_6_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_7_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_8_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_9_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_10_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_11_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_12_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_13_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_14_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_15_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_16_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_17_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_18_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_19_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_20_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_21_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_22_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_23_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_24_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_25_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_26_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_27_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_28_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_29_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_30_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_31_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_32_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_33_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_34_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_35_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_36_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_37_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_38_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_39_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_40_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_41_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_42_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_43_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_44_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_45_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_46_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_47_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_48_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_49_target_30_day_sales.pkl
# ✅ Model saved: models_30\1_50_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_1_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_2_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_3_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_4_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_5_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_6_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_7_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_8_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_9_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_10_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_11_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_12_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_13_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_14_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_15_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_16_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_17_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_18_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_19_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_20_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_21_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_22_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_23_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_24_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_25_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_26_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_27_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_28_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_29_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_30_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_31_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_32_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_33_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_34_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_35_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_36_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_37_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_38_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_39_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_40_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_41_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_42_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_43_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_44_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_45_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_46_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_47_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_48_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_49_target_30_day_sales.pkl
# ✅ Model saved: models_30\2_50_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_1_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_2_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_3_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_4_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_5_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_6_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_7_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_8_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_9_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_10_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_11_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_12_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_13_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_14_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_15_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_16_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_17_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_18_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_19_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_20_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_21_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_22_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_23_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_24_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_25_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_26_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_27_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_28_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_29_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_30_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_31_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_32_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_33_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_34_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_35_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_36_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_37_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_38_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_39_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_40_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_41_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_42_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_43_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_44_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_45_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_46_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_47_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_48_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_49_target_30_day_sales.pkl
# ✅ Model saved: models_30\3_50_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_1_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_2_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_3_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_4_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_5_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_6_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_7_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_8_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_9_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_10_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_11_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_12_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_13_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_14_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_15_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_16_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_17_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_18_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_19_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_20_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_21_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_22_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_23_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_24_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_25_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_26_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_27_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_28_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_29_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_30_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_31_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_32_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_33_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_34_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_35_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_36_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_37_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_38_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_39_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_40_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_41_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_42_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_43_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_44_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_45_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_46_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_47_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_48_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_49_target_30_day_sales.pkl
# ✅ Model saved: models_30\4_50_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_1_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_2_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_3_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_4_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_5_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_6_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_7_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_8_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_9_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_10_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_11_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_12_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_13_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_14_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_15_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_16_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_17_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_18_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_19_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_20_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_21_target_30_day_sales.pkl
# ✅ Model saved: models_30\5_22_target_30_day_sales.pkl
# ✅ Model saved: models_30\5